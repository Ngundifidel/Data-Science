# %%
import pandas 
data = pandas.read_csv("data/Advertising.csv")
data
# Out:
#       No     TV  Radio  Newspaper  Sales
# 0      1  230.1   37.8       69.2   22.1
# 1      2   44.5   39.3       45.1   10.4
# 2      3   17.2   45.9       69.3    9.3
# 3      4  151.5   41.3       58.5   18.5
# 4      5  180.8   10.8       58.4   12.9
# ..   ...    ...    ...        ...    ...
# 195  196   38.2    3.7       13.8    7.6
# 196  197   94.2    4.9        8.1    9.7
# 197  198  177.0    9.3        6.4   12.8
# 198  199  283.6   42.0       66.2   25.5
# 199  200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.isnull(). sum ()
# Out:
# No           0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data.groupby("TV").size()
# Out:
# TV
# 0.7      1
# 4.1      1
# 5.4      1
# 7.3      1
# 7.8      1
#         ..
# 289.7    1
# 290.7    1
# 292.9    1
# 293.6    1
# 296.4    1
# Length: 190, dtype: int64

# %%
data.groupby("TV").size()
# Out:
# TV
# 0.7      1
# 4.1      1
# 5.4      1
# 7.3      1
# 7.8      1
#         ..
# 289.7    1
# 290.7    1
# 292.9    1
# 293.6    1
# 296.4    1
# Length: 190, dtype: int64

# %%
# split the data in to qualitative and quantitative
array = data.values
array
X = array[:, 1: 4]

# X
Y=  array[:, 4:5]
# Y

# %%
# when uyou have qualitative abd quantitaitve data, how do you do analysis with it. using classification
# import skelarn
from sklearn import model_selection
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X,Y,train_size=0.3, random_state=42)

# %%
# lets pass our data through support vector classifier(SVr)
from sklearn.svm import SVR
model = SVR()
model.fit(X_train,Y_train )
# Out:
# /home/user/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
# lets test the model predication
svr_predict = model.predict(X_test)
svr_predict
# Out:
# array([15.18761682, 16.6161595 , 15.58279963,  9.29421935, 16.30240654,
#        11.66359075, 16.48353741,  9.03848723, 14.35915599, 14.77903309,
#         8.78743599,  9.22398545, 14.83777232,  8.50547739, 12.41592909,
#        13.87302868,  8.86839033, 15.06793278, 10.61151635, 15.63635177,
#        16.18041033, 12.5780386 ,  9.61778366, 16.28840706,  9.47530731,
#         8.88783978, 16.49577975, 12.80006325, 10.65191389,  8.44069082,
#        14.08052096, 10.11025643, 16.73503175, 10.70048458, 15.1667863 ,
#        15.83769106, 10.22491113, 15.86386959, 11.81292115,  8.19777151,
#        11.6910628 , 13.71713476,  9.61083771,  9.51634815, 14.35609066,
#         8.41240102, 10.38952264, 13.76003911, 11.29894774, 10.69300785,
#        11.97594419, 13.45193592, 10.30508578,  9.39752605,  9.59011556,
#        12.28873249, 10.06986391, 16.06617725,  8.48507236, 13.87710261,
#        14.73734088, 14.80223433, 12.31615173, 10.0046075 , 14.4737885 ,
# ...

# %%
# check the mode accuracy score
from sklearn.metrics import r2_score
check_accuracy = r2_score(svr_predict , Y_test) * 100
check_accuracy
# Out:
# -39.32503409983929

# %%
from sklearn.ensemble import RandomForestRegressor as rf 
model = rf()
model.fit(X_train,Y_train )
rf_predict = model.predict(X_test)
rf_predict
check_accuracy1 = r2_score(rf_predict , Y_test) * 100
check_accuracy1
# Out:
# /home/user/.local/lib/python3.10/site-packages/sklearn/base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 96.58575553239565

# %%
from sklearn.tree import DecisionTreeRegressor as dt 
model1 = dt()
model1.fit(X_train,Y_train )
dt_predict= model1.predict(X_test)
dt_predict
check_accuracy1 = r2_score(dt_predict , Y_test) * 100
check_accuracy1
# Out:
# 92.96252201334813

# %%
from sklearn.ensemble import GradientBoostingRegressor as gb 
model2 = gb()
model2.fit(X_train,Y_train )
gb_predict= model2.predict(X_test)
gb_predict
check_accuracy2 = r2_score(gb_predict , Y_test) * 100
check_accuracy2
# Out:
# /home/user/.local/lib/python3.10/site-packages/sklearn/ensemble/_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# 94.66970685371379

# %%
sales = [ [ 10,80, 10]]
svrcoutcome = model.predict(sales)
gbcoutcome = model1.predict(sales)
gradientoutcome = model2.predict(sales)

print (" svr says you sales will be", svrcoutcome)
print (" Decison treesays y you sales will be", gbcoutcome)
print (" Gradient boost says  you sales will be", gradientoutcome)
# Out:
#  svr says you sales will be [8.053]
#  Decison treesays y you sales will be [4.8]
#  Gradient boost says  you sales will be [3.25963798]
